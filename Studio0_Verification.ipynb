# %% [markdown]
# # COS 380 Studio 0 Verification Notebook
# ## Build and verify your NLP workspace
#
# This notebook is not an NLP lab. Its purpose is to make sure your computer and course folder are ready for every later lab.
#
# By the end, you should see **Setup status: READY**.

# %% [markdown]
# ## 1. Confirm where this notebook is running
#
# Place this notebook in the **root `COS380_NLP/` folder** for Studio 0. Later lab notebooks will live inside `labs/labXX/`.

# %%
from pathlib import Path
import sys

COURSE_ROOT = Path.cwd().resolve()
print('Course root:', COURSE_ROOT)
print('Folder name:', COURSE_ROOT.name)
# Out:
# Course root: /Users/grace/github/COS380_NLP
# Folder name: COS380_NLP

# %% [markdown]
# ## 2. Verify Python

# %%
import sys
print('Python version:', sys.version)
print('Python executable:', sys.executable)
# Out:
# Python version: 3.13.7 (v3.13.7:bcee1c32211, Aug 14 2025, 19:10:51) [Clang 16.0.0 (clang-1600.0.26.6)]
# Python executable: /Users/grace/github/COS380_NLP/.venv/bin/python

# %% [markdown]
# ## 3. Verify core course packages
#
# If this cell fails because a package is missing, return to the Studio 0 manual and install the required packages in your course virtual environment.

# %%
import numpy as np
import pandas as pd
import matplotlib
import nltk
import sklearn
import spacy

print('Core imports succeeded.')
# Out:
# Core imports succeeded.

# %% [markdown]
# ## 4. Verify the two reusable-code areas
#
# - `nlp_toolkit/` is **your code**. It grows as you complete labs.
# - `course_tools/` is **instructor-provided support code**. Do not edit it unless instructed.

# %%
import nlp_toolkit
from course_tools.cos380_checks import course_setup_check

print('nlp_toolkit import: OK')
print('course_tools import: OK')
# Out:
# nlp_toolkit import: OK
# course_tools import: OK

# %% [markdown]
# ## 5. Inspect the course folder structure

# %%
required = [
    'data', 'labs', 'nlp_toolkit', 'course_tools',
    'project', 'resources', 'README.md', 'requirements.txt'
]

for name in required:
    path = COURSE_ROOT / name
    print(f'{name:<20}', 'FOUND' if path.exists() else 'MISSING')
# Out:
# data                 FOUND
# labs                 FOUND
# nlp_toolkit          FOUND
# course_tools         FOUND
# project              FOUND
# resources            FOUND
# README.md            FOUND
# requirements.txt     FOUND

# %% [markdown]
# ## 6. Dataset folders
#
# The folders are created now so later lab instructions are consistent. Your instructor may release datasets as they are needed. Do not download substitute datasets unless instructed.

# %%
data_dirs = [
    'airline_tweets', 'bbc_news', 'poetry',
    'movie_reviews', 'spam_ham'
]

for name in data_dirs:
    path = COURSE_ROOT / 'data' / name
    print(f'data/{name:<18}', 'FOUND' if path.exists() else 'MISSING')
# Out:
# data/airline_tweets     FOUND
# data/bbc_news           FOUND
# data/poetry             FOUND
# data/movie_reviews      FOUND
# data/spam_ham           FOUND

# %% [markdown]
# ## 7. Final setup check
#
# This is the same course-provided self-check system that later labs will use. In later labs, you will call functions such as `validate_lab1(...)` or `validate_lab4(...)` before submitting.

# %%
course_setup_check(COURSE_ROOT)
# Out:
# ...
# COS 380 COURSE SETUP CHECK
# ...
# ✓ data/ folder found
# ✓ labs/ folder found
# ✓ nlp_toolkit/ folder found
# ✓ course_tools/ folder found
# ✓ project/ folder found
# ✓ resources/ folder found
# ✓ nlp_toolkit/__init__.py found
# ✓ course_tools/__init__.py found
# ✓ course_tools/cos380_checks.py found
# ✓ README.md found
# ✓ Python package 'numpy' available
# ✓ Python package 'pandas' available
# ✓ Python package 'nltk' available
# ✓ Python package 'sklearn' available
# ✓ Python package 'matplotlib' available
# --------------------------------------------------------------
# Setup status: READY
# Course root: /Users/grace/github/COS380_NLP
# ...
# True

# %% [markdown]
# ## 8. Short reflection
#
#
# **1. Why do we keep reusable NLP functions in `nlp_toolkit/` instead of copying them into every notebook?**
#
#     We keep reusable functions in a toolkit so that they are in one spot and easily findable. It also makes the code more sharable and replicable because other people will see what we used
#
# **2. What is the purpose of the `data/` folder?**
#
#     The data folder is to store various datasets. Having our data in the data folder puts it in a clearly labled spot thats easy to find and share. Also, the data is what we apply our code to in order to show results.

# %% [markdown]
# ## Studio 0 completion checklist
#
# - [x] Course folder created
# - [x] Virtual environment created and activated
# - [x] Required packages installed
# - [x] `nlp_toolkit/` imports successfully
# - [x] `course_tools/` imports successfully
# - [x] Dataset folders exist
# - [x] `course_setup_check()` reports **READY**
# - [x] Reflection completed
